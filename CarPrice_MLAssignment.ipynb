# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive/AI_assignment

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import pandas as pd
import numpy as np
car_data = pd.read_csv('/content/drive/MyDrive/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

# %%
car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# ```
# #WE will configure different models here according to relu, tanh , regularization, dropout etc..
# ```

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# ## here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f65045715f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6503388f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6505f75f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6503333200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6507aa5f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6507aa5ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6507a0e9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6507a72050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.7909 - mae: 0.7167
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8968 - mae: 0.6962
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7605 - mae: 0.6846
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5864 - mae: 0.6232
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4889 - mae: 0.5775
# Epoch 6/100
# 106/106 [==============================] - 0s 976us/step - loss: 0.5563 - mae: 0.5506
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5315 - mae: 0.5096
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7233 - mae: 0.5292
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5346 - mae: 0.4555
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4893 - mae: 0.4588
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4230 - mae: 0.4162
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5147 - mae: 0.4638
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4296 - mae: 0.4178
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2652 - mae: 0.3785
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3120 - mae: 0.3454
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4917 - mae: 0.4345
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2907 - mae: 0.3614
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2332 - mae: 0.3346
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2996 - mae: 0.3022
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2807 - mae: 0.3273
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4388 - mae: 0.4263
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4729 - mae: 0.3765
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1798 - mae: 0.2985
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7024 - mae: 0.4645
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2935 - mae: 0.3180
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1392 - mae: 0.2604
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4855 - mae: 0.3708
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1942 - mae: 0.2640
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3219 - mae: 0.3374
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3704 - mae: 0.3723
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3389 - mae: 0.3253
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4574 - mae: 0.3694
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.3716
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1299 - mae: 0.2285
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1322 - mae: 0.2494
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2001 - mae: 0.2444
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3189 - mae: 0.3296
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2843 - mae: 0.3416
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2299 - mae: 0.2539
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2297 - mae: 0.3070
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2888 - mae: 0.3008
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3522 - mae: 0.3786
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2125 - mae: 0.3067
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1407 - mae: 0.2553
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3920 - mae: 0.2806
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2848 - mae: 0.3332
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1814 - mae: 0.2826
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1889 - mae: 0.2402
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2094 - mae: 0.3064
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1285 - mae: 0.2767
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2222 - mae: 0.2329
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2163 - mae: 0.2889
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3696 - mae: 0.3181
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3132 - mae: 0.3571
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1584 - mae: 0.2456
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2558 - mae: 0.3162
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2102 - mae: 0.2611
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3953 - mae: 0.3384
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2867 - mae: 0.3055
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1531 - mae: 0.2471
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2889 - mae: 0.3104
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2649 - mae: 0.2444
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2981 - mae: 0.2374
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1475 - mae: 0.2187
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3887 - mae: 0.3167
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3641 - mae: 0.3075
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1472 - mae: 0.2572
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1591 - mae: 0.2298
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1211 - mae: 0.1981
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1735 - mae: 0.2625
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1770 - mae: 0.2493
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1971 - mae: 0.2805
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2272 - mae: 0.2750
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1718 - mae: 0.2617
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2760 - mae: 0.2968
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3014 - mae: 0.3007
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3224 - mae: 0.2804
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0861 - mae: 0.2006
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4600 - mae: 0.3817
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3661 - mae: 0.3280
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1294 - mae: 0.2332
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2771 - mae: 0.2760
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3013 - mae: 0.3190
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1616 - mae: 0.2187
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1550 - mae: 0.2328
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1807 - mae: 0.2934
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1514 - mae: 0.2366
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.2925
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2192 - mae: 0.2795
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1425 - mae: 0.2330
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2672 - mae: 0.2849
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2894 - mae: 0.2999
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2618 - mae: 0.2927
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1684 - mae: 0.2391
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2530 - mae: 0.3244
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1576 - mae: 0.2687
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1878 - mae: 0.2600
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2120 - mae: 0.2683
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3072 - mae: 0.3248
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2088 - mae: 0.2817
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6505394290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3957 - mae: 0.4140
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.2385 - mae: 0.8117
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5480 - mae: 0.5597
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4134 - mae: 0.4964
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4841 - mae: 0.4668
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4942 - mae: 0.5111
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4610 - mae: 0.4774
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7845 - mae: 0.6003
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3513 - mae: 0.4384
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3787 - mae: 0.4232
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3965 - mae: 0.4449
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4975 - mae: 0.4582
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4039 - mae: 0.4240
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5487 - mae: 0.4794
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4125 - mae: 0.4633
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3695 - mae: 0.3832
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3259 - mae: 0.4003
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3058 - mae: 0.3750
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4043 - mae: 0.4065
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3750 - mae: 0.4148
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2613 - mae: 0.3526
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5591 - mae: 0.4749
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2852 - mae: 0.3852
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2878 - mae: 0.3637
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2887 - mae: 0.3967
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3609 - mae: 0.4110
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5819 - mae: 0.4485
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3106 - mae: 0.3777
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2939 - mae: 0.3467
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2914 - mae: 0.3657
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3388 - mae: 0.3878
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2097 - mae: 0.3378
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2538 - mae: 0.3697
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2178 - mae: 0.3320
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2146 - mae: 0.3271
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3124 - mae: 0.3530
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2035 - mae: 0.3000
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2077 - mae: 0.3011
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1989 - mae: 0.3359
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1373 - mae: 0.2843
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3852 - mae: 0.3662
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2393 - mae: 0.3446
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7364 - mae: 0.4684
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2112 - mae: 0.3118
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1546 - mae: 0.2741
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2503 - mae: 0.3062
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3990 - mae: 0.3534
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1528 - mae: 0.2940
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1664 - mae: 0.3067
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1317 - mae: 0.2805
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1654 - mae: 0.2622
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2257 - mae: 0.3221
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2414 - mae: 0.3456
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2049 - mae: 0.3078
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3433 - mae: 0.3491
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3630 - mae: 0.3534
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2397 - mae: 0.2759
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1246 - mae: 0.2436
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0825 - mae: 0.2191
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1643 - mae: 0.2755
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1223 - mae: 0.2325
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1332 - mae: 0.2551
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3039 - mae: 0.3652
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3604 - mae: 0.3388
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2148 - mae: 0.2929
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1808 - mae: 0.2707
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1936 - mae: 0.3293
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1775 - mae: 0.2971
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2589 - mae: 0.3443
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1353 - mae: 0.2890
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1745 - mae: 0.2992
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2766 - mae: 0.3163
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1619 - mae: 0.2730
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1821 - mae: 0.2569
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2601 - mae: 0.3253
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2086 - mae: 0.2624
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1587 - mae: 0.2936
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1108 - mae: 0.2103
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1130 - mae: 0.2626
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1282 - mae: 0.2491
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2347 - mae: 0.2533
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1482 - mae: 0.2819
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2598 - mae: 0.2709
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1650 - mae: 0.2793
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3567 - mae: 0.3114
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1435 - mae: 0.2707
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3448 - mae: 0.2959
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1598 - mae: 0.2687
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2453 - mae: 0.2889
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1292 - mae: 0.2548
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1611 - mae: 0.2886
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1271 - mae: 0.2318
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1538 - mae: 0.2439
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1933 - mae: 0.2734
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1348 - mae: 0.2365
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3877 - mae: 0.3267
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3014 - mae: 0.3056
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1153 - mae: 0.2554
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0966 - mae: 0.2108
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1275 - mae: 0.2515
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2947 - mae: 0.3040
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f650fd57d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4303 - mae: 0.3677
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9582 - mae: 0.8176
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6340 - mae: 0.6343
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6142 - mae: 0.5952
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3608 - mae: 0.4669
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4242 - mae: 0.4564
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5085 - mae: 0.4641
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3411 - mae: 0.4451
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5184 - mae: 0.4449
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5748 - mae: 0.4452
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4445 - mae: 0.4462
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3207 - mae: 0.3829
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5009 - mae: 0.4216
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2823 - mae: 0.3532
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3691 - mae: 0.4105
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6292 - mae: 0.4344
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3653 - mae: 0.4112
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5268 - mae: 0.4100
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3616 - mae: 0.3767
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6508 - mae: 0.4778
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2561 - mae: 0.3213
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3129 - mae: 0.3286
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3125 - mae: 0.3912
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4373 - mae: 0.4334
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1683 - mae: 0.2745
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2770 - mae: 0.3390
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3430 - mae: 0.3590
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1899 - mae: 0.3167
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1339 - mae: 0.2898
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3808 - mae: 0.4212
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2406 - mae: 0.3129
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3634 - mae: 0.3354
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3686 - mae: 0.3518
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2990 - mae: 0.3330
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8968 - mae: 0.5001
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1632 - mae: 0.2906
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1619 - mae: 0.3036
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2210 - mae: 0.3127
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6412 - mae: 0.4063
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1241 - mae: 0.2681
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2471 - mae: 0.2894
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2496 - mae: 0.2716
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4041 - mae: 0.3733
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2673 - mae: 0.2856
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1972 - mae: 0.2962
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3739 - mae: 0.3357
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2417 - mae: 0.3072
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1961 - mae: 0.3030
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1423 - mae: 0.2090
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1752 - mae: 0.2865
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4055 - mae: 0.4093
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3808 - mae: 0.3594
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2820 - mae: 0.3561
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1241 - mae: 0.2336
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2398 - mae: 0.3204
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7223 - mae: 0.4524
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2070 - mae: 0.3115
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3206 - mae: 0.3232
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2314 - mae: 0.3113
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3499 - mae: 0.3620
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2253 - mae: 0.3504
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2135 - mae: 0.3232
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1980 - mae: 0.3096
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1344 - mae: 0.2418
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3097 - mae: 0.3456
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2051 - mae: 0.3010
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2459 - mae: 0.3020
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1302 - mae: 0.2291
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5038 - mae: 0.3745
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3171 - mae: 0.3142
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1138 - mae: 0.2351
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4991 - mae: 0.3535
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3479 - mae: 0.3596
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1323 - mae: 0.2518
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1715 - mae: 0.2604
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1584 - mae: 0.2363
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1045 - mae: 0.2240
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2573 - mae: 0.3444
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1687 - mae: 0.2620
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1990 - mae: 0.3032
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3618 - mae: 0.3262
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1717 - mae: 0.2605
# Epoch 82/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1895 - mae: 0.2468
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1254 - mae: 0.2184
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1750 - mae: 0.2630
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3487 - mae: 0.3301
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4753 - mae: 0.3359
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3063 - mae: 0.3150
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3259 - mae: 0.3463
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1699 - mae: 0.2677
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2563 - mae: 0.3238
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2412 - mae: 0.3257
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1722 - mae: 0.2642
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1207 - mae: 0.2282
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2801 - mae: 0.3162
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1683 - mae: 0.2766
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3230 - mae: 0.3562
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3609 - mae: 0.3360
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2105 - mae: 0.2708
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2208 - mae: 0.2829
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1619 - mae: 0.2776
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f65033404d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3700 - mae: 0.3573
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8083 - mae: 0.6999
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9223 - mae: 0.7422
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8138 - mae: 0.7003
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7398 - mae: 0.6691
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6830 - mae: 0.6303
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9967 - mae: 0.6965
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3475 - mae: 0.4412
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3488 - mae: 0.4092
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4018 - mae: 0.4292
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4344 - mae: 0.4742
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6126 - mae: 0.5052
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6126 - mae: 0.5307
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5179 - mae: 0.4767
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3946 - mae: 0.4387
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4198 - mae: 0.4245
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5891 - mae: 0.5012
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4888 - mae: 0.4437
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3034 - mae: 0.3673
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3022 - mae: 0.3975
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4455 - mae: 0.3934
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2863 - mae: 0.3954
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2475 - mae: 0.3520
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3586 - mae: 0.3983
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4605 - mae: 0.3937
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3422 - mae: 0.3773
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3690 - mae: 0.3770
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3054 - mae: 0.3612
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2624 - mae: 0.3534
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1640 - mae: 0.2688
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4229 - mae: 0.4273
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3973 - mae: 0.3922
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2250 - mae: 0.3108
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2744 - mae: 0.3098
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3899 - mae: 0.4084
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5054 - mae: 0.3660
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4069 - mae: 0.3817
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3463 - mae: 0.3574
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1630 - mae: 0.2853
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1773 - mae: 0.2923
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2924 - mae: 0.3105
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2493 - mae: 0.3266
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1767 - mae: 0.2833
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2528 - mae: 0.3308
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1765 - mae: 0.2841
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4508 - mae: 0.4087
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4309 - mae: 0.3871
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4959 - mae: 0.3778
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5072 - mae: 0.4376
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1425 - mae: 0.2556
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2824 - mae: 0.3353
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2661 - mae: 0.3306
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3001 - mae: 0.3141
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7798 - mae: 0.4611
# Epoch 54/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2191 - mae: 0.3047
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2998 - mae: 0.3585
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3803 - mae: 0.3694
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3011 - mae: 0.3496
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5053 - mae: 0.4229
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2169 - mae: 0.2787
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4574 - mae: 0.3673
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7602 - mae: 0.4811
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4160 - mae: 0.3714
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2126 - mae: 0.2935
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2296 - mae: 0.3161
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2904 - mae: 0.2588
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1515 - mae: 0.2907
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3576 - mae: 0.3365
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4488 - mae: 0.3457
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3510 - mae: 0.3743
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1955 - mae: 0.2768
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1439 - mae: 0.2453
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2834 - mae: 0.2877
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2449 - mae: 0.3264
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1541 - mae: 0.2602
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3515 - mae: 0.3677
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3765 - mae: 0.3821
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2861 - mae: 0.3223
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1518 - mae: 0.2261
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2624 - mae: 0.3385
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1435 - mae: 0.2686
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5319 - mae: 0.4461
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2055 - mae: 0.2925
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2365 - mae: 0.3123
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2742 - mae: 0.3118
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3737 - mae: 0.3383
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2319 - mae: 0.3026
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2896 - mae: 0.3431
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4547 - mae: 0.3664
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2325 - mae: 0.3144
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2963 - mae: 0.3173
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2426 - mae: 0.3225
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4211 - mae: 0.3771
# Epoch 93/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2608 - mae: 0.3002
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1552 - mae: 0.2565
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2712 - mae: 0.3094
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1911 - mae: 0.2506
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1169 - mae: 0.2054
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2845 - mae: 0.3236
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1663 - mae: 0.2418
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3047 - mae: 0.3284
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f65056d7b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1666 - mae: 0.2792

# %% [markdown]
# # Scores
# ## here we will see  MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.29688599705696106,
#  0.294673353433609,
#  0.3749537765979767,
#  0.36299845576286316]

# %%
all_scores_tanh
# Out:
# [0.3067643642425537,
#  0.43865180015563965,
#  0.4393984377384186,
#  0.31109175086021423]

# %%
all_scores_regular
# Out:
# [0.35697850584983826,
#  0.262533962726593,
#  0.34966960549354553,
#  0.44781798124313354]

# %%
all_scores_drop
# Out:
# [0.414002925157547, 0.3677144944667816, 0.357318252325058, 0.2792072296142578]

# %% [markdown]
# # training on the training data
# ## here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6504557560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1137 - mae: 0.2457

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6504557cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1157 - mae: 0.2623

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6506827b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1105 - mae: 0.2071

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f650532fd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1099 - mae: 0.2491

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[15885.13]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21258.826]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[23794.322]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20103.184]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f65032e17a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f650449b5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f650561d200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f65021998c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
