# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # **Load Data**

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
data = pd.read_csv('/content/drive/MyDrive/creditcard.csv')

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# # **Check Missing Values ( If Exist ; Fill each record with mean of its feature )**

# %%
# %time data.isnull().any()
# Out:
# CPU times: user 14.3 ms, sys: 1.87 ms, total: 16.2 ms
# Wall time: 16.8 ms
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %% [markdown]
# # **Standardized the Input Variables**

# %%
data.reset_index(drop=True, inplace=True)
labels = data.pop('Class')

# %%
data -= data.mean()
data /= data.std()

# %%
data.describe()
# Out:
#                Time            V1  ...           V28        Amount
# count  2.848070e+05  2.848070e+05  ...  2.848070e+05  2.848070e+05
# mean  -1.137547e-15 -2.369347e-15  ... -3.725646e-17  2.278134e-13
# std    1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
# min   -1.996580e+00 -2.879850e+01  ... -4.674604e+01 -3.532288e-01
# 25%   -8.552105e-01 -4.698909e-01  ... -1.604437e-01 -3.308395e-01
# 50%   -2.131450e-01  9.245335e-03  ...  3.406362e-02 -2.652710e-01
# 75%    9.372158e-01  6.716927e-01  ...  2.371521e-01 -4.471699e-02
# max    1.642055e+00  1.253349e+00  ...  1.025432e+02  1.023621e+02
#
# [8 rows x 30 columns]

# %% [markdown]
# # **Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).**

# %%
data_len = len(data)
train_data = data.iloc[:data_len*50//100]
val_data = data.iloc[data_len*50//100:data_len*70//100]
test_data = data.iloc[data_len*70//100:]
labels_len = len(labels)
train_labels = labels.iloc[:labels_len*50//100]
val_labels = labels.iloc[labels_len*50//100:labels_len*70//100]
test_labels = labels.iloc[labels_len*70//100:]

# %% [markdown]
# # **Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).**

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
import tensorflow as tf
network = models.Sequential()
network.add(layers.Dense(10,activation="tanh",input_shape=(len(train_data.columns),) ))
network.add(layers.Dense(8,activation="tanh",input_shape=(data.shape[1],) ))
network.add(layers.Dense(6,activation="tanh",input_shape=(data.shape[1],) ))
network.add(layers.Dense(1,activation="sigmoid"))
network.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
with tf.device('/device:GPU:1'):
  # %time MODEL = network.fit(train_data,train_labels,epochs=10,batch_size=256,validation_data=(val_data,val_labels))
# Out:
# Epoch 1/10
# 557/557 [==============================] - 5s 3ms/step - loss: 0.2693 - acc: 0.8863 - val_loss: 0.6190 - val_acc: 0.7510
# Epoch 2/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0037 - acc: 0.9993 - val_loss: 0.6668 - val_acc: 0.7572
# Epoch 3/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0037 - acc: 0.9992 - val_loss: 0.6379 - val_acc: 0.7790
# Epoch 4/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0035 - acc: 0.9992 - val_loss: 0.6188 - val_acc: 0.7928
# Epoch 5/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0030 - acc: 0.9994 - val_loss: 0.4822 - val_acc: 0.8333
# Epoch 6/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0032 - acc: 0.9993 - val_loss: 0.5106 - val_acc: 0.8257
# Epoch 7/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0033 - acc: 0.9994 - val_loss: 0.3583 - val_acc: 0.8658
# Epoch 8/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9995 - val_loss: 0.3840 - val_acc: 0.8599
# Epoch 9/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0028 - acc: 0.9994 - val_loss: 0.3336 - val_acc: 0.8786
# Epoch 10/10
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0026 - acc: 0.9994 - val_loss: 0.2604 - val_acc: 0.8995
# CPU times: user 21.8 s, sys: 2.28 s, total: 24 s
# Wall time: 20.9 s

# %%
test_loss , test_acc = network.evaluate(test_data,test_labels)
# Out:
# 2671/2671 [==============================] - 4s 2ms/step - loss: 1.0083 - acc: 0.6635

# %%
test_labels[test_labels == 1]
# Out:
# 199896    1
# 201098    1
# 201601    1
# 203324    1
# 203328    1
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 108, dtype: int64

# %%
history_dict = MODEL.history
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
epoches = np.arange(1,len(history_dict['acc'])+1)
plt.plot(epoches,acc_values,'ro',label="Training Accuracy")
plt.plot(epoches,val_acc_values,'b-',label="Validation Accuracy")
plt.title('Training and validation Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Accuracy")
plt.legend()
# plt.show()

# %% [markdown]
# # **Doing With RELU**

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
import tensorflow as tf
network1 = models.Sequential()
network1.add(layers.Dense(30,activation="relu",input_shape=(len(train_data.columns),) ))
network1.add(layers.Dense(20,activation="relu",input_shape=(data.shape[1],) ))
network1.add(layers.Dense(10,activation="relu",input_shape=(data.shape[1],) ))
network1.add(layers.Dense(1,activation="sigmoid"))
network1.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
with tf.device('/device:GPU:1'):
  # %time MODEL1 = network1.fit(train_data,train_labels,epochs=10,batch_size=512,validation_data=(val_data,val_labels))
# Out:
# Epoch 1/10
# 279/279 [==============================] - 2s 4ms/step - loss: 0.1160 - acc: 0.9982 - val_loss: 0.0128 - val_acc: 0.9992
# Epoch 2/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0038 - acc: 0.9993 - val_loss: 0.0109 - val_acc: 0.9991
# Epoch 3/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0038 - acc: 0.9992 - val_loss: 0.0089 - val_acc: 0.9986
# Epoch 4/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0030 - acc: 0.9993 - val_loss: 0.0086 - val_acc: 0.9984
# Epoch 5/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 0.0097 - val_acc: 0.9981
# Epoch 6/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 0.0087 - val_acc: 0.9982
# Epoch 7/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 0.0096 - val_acc: 0.9978
# Epoch 8/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0023 - acc: 0.9995 - val_loss: 0.0082 - val_acc: 0.9983
# Epoch 9/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 0.0100 - val_acc: 0.9978
# Epoch 10/10
# 279/279 [==============================] - 1s 3ms/step - loss: 0.0022 - acc: 0.9995 - val_loss: 0.0106 - val_acc: 0.9978
# CPU times: user 11.6 s, sys: 939 ms, total: 12.5 s
# Wall time: 9.77 s

# %%
history_dict = MODEL1.history
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
epoches = np.arange(1,len(history_dict['acc'])+1)
plt.plot(epoches,acc_values,'ro',label="Training Accuracy")
plt.plot(epoches,val_acc_values,'b',label="Validation Accuracy")
plt.title('Training and validation Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # **Evaluation Step**

# %%
test_loss , test_acc = network1.evaluate(test_data,test_labels)
# Out:
# 2671/2671 [==============================] - 4s 2ms/step - loss: 0.0107 - acc: 0.9981

# %% [markdown]
# # **Predict**

# %%
prediction_test_data = test_data
predictions = network1.predict(prediction_test_data)
hit = np.argmax(predictions) == np.array(test_labels)
print(f"{len(hit)} out of {len(predictions)} ")
# Out:
# 85443 out of 85443

# %%
print(f"Alhamdullah Accuracy is upto {test_acc*100}%")
# Out:
# Alhamdullah Accuracy is upto 99.80571866035461%
