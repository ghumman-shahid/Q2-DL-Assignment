# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data .

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.1.5'

# %%
np.__version__
# Out:
# '1.19.5'

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %% [markdown]
# Loading data...

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/

# %%
# Load the dataset.
df = pd.read_csv('/content/drive/MyDrive/ionosphere_data.csv', delimiter=',')

# %%
# Find the shape of the dataset 
df.shape
# Out:
# (351, 35)

# %% [markdown]
# It's clear from the shape of the data that dataset is not a huge one. Only 351 records are available with 34 features/columns.

# %%
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df.describe().T
# Out:
#            count      mean       std  min       25%      50%       75%  max
# feature1   351.0  0.891738  0.311155  0.0  1.000000  1.00000  1.000000  1.0
# feature2   351.0  0.000000  0.000000  0.0  0.000000  0.00000  0.000000  0.0
# feature3   351.0  0.641342  0.497708 -1.0  0.472135  0.87111  1.000000  1.0
# feature4   351.0  0.044372  0.441435 -1.0 -0.064735  0.01631  0.194185  1.0
# feature5   351.0  0.601068  0.519862 -1.0  0.412660  0.80920  1.000000  1.0
# feature6   351.0  0.115889  0.460810 -1.0 -0.024795  0.02280  0.334655  1.0
# feature7   351.0  0.550095  0.492654 -1.0  0.211310  0.72873  0.969240  1.0
# feature8   351.0  0.119360  0.520750 -1.0 -0.054840  0.01471  0.445675  1.0
# feature9   351.0  0.511848  0.507066 -1.0  0.087110  0.68421  0.953240  1.0
# feature10  351.0  0.181345  0.483851 -1.0 -0.048075  0.01829  0.534195  1.0
# feature11  351.0  0.476183  0.563496 -1.0  0.021120  0.66798  0.957895  1.0
# feature12  351.0  0.155040  0.494817 -1.0 -0.065265  0.02825  0.482375  1.0
# feature13  351.0  0.400801  0.622186 -1.0  0.000000  0.64407  0.955505  1.0
# feature14  351.0  0.093414  0.494873 -1.0 -0.073725  0.03027  0.374860  1.0
# feature15  351.0  0.344159  0.652828 -1.0  0.000000  0.60194  0.919330  1.0
# feature16  351.0  0.071132  0.458371 -1.0 -0.081705  0.00000  0.308975  1.0
# feature17  351.0  0.381949  0.618020 -1.0  0.000000  0.59091  0.935705  1.0
# feature18  351.0 -0.003617  0.496762 -1.0 -0.225690  0.00000  0.195285  1.0
# feature19  351.0  0.359390  0.626267 -1.0  0.000000  0.57619  0.899265  1.0
# feature20  351.0 -0.024025  0.519076 -1.0 -0.234670  0.00000  0.134370  1.0
# feature21  351.0  0.336695  0.609828 -1.0  0.000000  0.49909  0.894865  1.0
# feature22  351.0  0.008296  0.518166 -1.0 -0.243870  0.00000  0.188760  1.0
# feature23  351.0  0.362475  0.603767 -1.0  0.000000  0.53176  0.911235  1.0
# feature24  351.0 -0.057406  0.527456 -1.0 -0.366885  0.00000  0.164630  1.0
# feature25  351.0  0.396135  0.578451 -1.0  0.000000  0.55389  0.905240  1.0
# feature26  351.0 -0.071187  0.508495 -1.0 -0.332390 -0.01505  0.156765  1.0
# feature27  351.0  0.541641  0.516205 -1.0  0.286435  0.70824  0.999945  1.0
# feature28  351.0 -0.069538  0.550025 -1.0 -0.443165 -0.01769  0.153535  1.0
# feature29  351.0  0.378445  0.575886 -1.0  0.000000  0.49664  0.883465  1.0
# feature30  351.0 -0.027907  0.507974 -1.0 -0.236885  0.00000  0.154075  1.0
# feature31  351.0  0.352514  0.571483 -1.0  0.000000  0.44277  0.857620  1.0
# feature32  351.0 -0.003794  0.513574 -1.0 -0.242595  0.00000  0.200120  1.0
# feature33  351.0  0.349364  0.522663 -1.0  0.000000  0.40956  0.813765  1.0
# feature34  351.0  0.014480  0.468337 -1.0 -0.165350  0.00000  0.171660  1.0

# %%
for feature in df:
    print(feature)
    print(len(df[feature].unique()))
# Out:
# feature1
# 2
# feature2
# 1
# feature3
# 219
# feature4
# 269
# feature5
# 204
# feature6
# 259
# feature7
# 231
# feature8
# 260
# feature9
# 244
# feature10
# 267
# feature11
# 246
# feature12
# 269
# feature13
# 238
# feature14
# 266
# feature15
# 234
# feature16
# 270
# feature17
# 254
# feature18
# 280
# feature19
# 254
# feature20
# 266
# feature21
# 248
# feature22
# 265
# feature23
# 248
# feature24
# 264
# feature25
# 256
# feature26
# 273
# feature27
# 256
# feature28
# 281
# feature29
# 244
# feature30
# 266
# feature31
# 243
# feature32
# 263
# feature33
# 245
# feature34
# 263
# label
# 2

# %%
df['feature2'].unique()
# Out:
# array([0])

# %%
df.drop(df.columns[1], inplace=True, axis=1)

# %%
df.head()
# Out:
#    feature1  feature3  feature4  ...  feature33  feature34  label
# 0         1   0.99539  -0.05889  ...    0.18641   -0.45300      g
# 1         1   1.00000  -0.18829  ...   -0.13738   -0.02447      b
# 2         1   1.00000  -0.03365  ...    0.56045   -0.38238      g
# 3         1   1.00000  -0.45161  ...   -0.32382    1.00000      b
# 4         1   1.00000  -0.02401  ...   -0.04608   -0.65697      g
#
# [5 rows x 34 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 34 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature3   351 non-null    float64
#  2   feature4   351 non-null    float64
#  3   feature5   351 non-null    float64
#  4   feature6   351 non-null    float64
#  5   feature7   351 non-null    float64
#  6   feature8   351 non-null    float64
#  7   feature9   351 non-null    float64
#  8   feature10  351 non-null    float64
#  9   feature11  351 non-null    float64
#  10  feature12  351 non-null    float64
#  11  feature13  351 non-null    float64
#  12  feature14  351 non-null    float64
#  13  feature15  351 non-null    float64
#  14  feature16  351 non-null    float64
#  15  feature17  351 non-null    float64
#  16  feature18  351 non-null    float64
#  17  feature19  351 non-null    float64
#  18  feature20  351 non-null    float64
#  19  feature21  351 non-null    float64
#  20  feature22  351 non-null    float64
#  21  feature23  351 non-null    float64
#  22  feature24  351 non-null    float64
#  23  feature25  351 non-null    float64
#  24  feature26  351 non-null    float64
#  25  feature27  351 non-null    float64
#  26  feature28  351 non-null    float64
#  27  feature29  351 non-null    float64
#  28  feature30  351 non-null    float64
#  29  feature31  351 non-null    float64
#  30  feature32  351 non-null    float64
#  31  feature33  351 non-null    float64
#  32  feature34  351 non-null    float64
#  33  label      351 non-null    object
# dtypes: float64(32), int64(1), object(1)
# memory usage: 93.4+ KB

# %%
'''for feature in df:
    print(feature)
    df[feature].hist()
    plt.show()'''

# df.hist()
# plt.show()
# Out:
# 'for feature in df:\n    print(feature)\n    df[feature].hist()\n    plt.show()'

# %%
# Check summary statistics
df.describe()
# Out:
#          feature1    feature3    feature4  ...   feature32   feature33   feature34
# count  351.000000  351.000000  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738    0.641342    0.044372  ...   -0.003794    0.349364    0.014480
# std      0.311155    0.497708    0.441435  ...    0.513574    0.522663    0.468337
# min      0.000000   -1.000000   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000    0.472135   -0.064735  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000    0.871110    0.016310  ...    0.000000    0.409560    0.000000
# 75%      1.000000    1.000000    0.194185  ...    0.200120    0.813765    0.171660
# max      1.000000    1.000000    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.

# %%
# Find missing values
df.isnull().sum()
# Out:
# feature1     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
df['label'] = [1 if lbl == 'g' else 0 for lbl in df['label']]

# %%
train_data = df.sample(frac= 0.6, random_state=125)
test_data = df.drop(train_data.index)

# %%
train_label = train_data.iloc[:,-1]
train_data = train_data.iloc[:,0:-1]
test_label = test_data.iloc[:,-1]
test_data = test_data.iloc[:,0:-1]

# %%
# df.drop(columns= 'label', inplace = True)

# %%
train_data.head()
# Out:
#      feature1  feature3  feature4  ...  feature32  feature33  feature34
# 270         1   1.00000   0.08013  ...   -0.03464    0.92226   -0.03673
# 116         1   1.00000  -0.14754  ...   -0.44262    0.49180   -0.06557
# 135         1   0.89706   0.38235  ...   -0.50735   -0.28676   -0.56618
# 91          1   0.84557  -0.08580  ...   -0.78170   -0.18494   -0.59867
# 100         1   1.00000  -1.00000  ...   -1.00000    0.00000    0.00000
#
# [5 rows x 33 columns]

# %%
train_label
# Out:
# 270    1
# 116    0
# 135    1
# 91     0
# 100    0
#       ..
# 213    1
# 161    1
# 141    1
# 59     0
# 113    1
# Name: label, Length: 211, dtype: int64

# %% [markdown]
# - Standardized the Input Variables. **Hint**: Centeralized the data

# %%
# Normalize the data
# train_mean = train_data.mean()
# train_data -= train_mean
# train_std = train_data.std()
# train_data /= train_std
# test_data -= train_mean
# test_data /= train_std

# %% [markdown]
# - Encode labels.

# %% [markdown]
# - Shuffle the data if needed.
# - Split into 60 and 40 ratio.

# %%
# Now sample the dataframe

# %%
train_data.shape
# Out:
# (211, 33)

# %%
test_data.shape
# Out:
# (140, 33)

# %%
train_label.shape
# Out:
# (211,)

# %%
test_label.shape
# Out:
# (140,)

# %%
train_label.sum()
# Out:
# 140

# %%
len(train_label)
# Out:
# 211

# %%
# train_label.sum()/len(train_label)

# %% [markdown]
# ### Data Preprocessing

# %%
train_data = train_data.to_numpy()

# %%
train_label = train_label.to_numpy().astype('float32')

# %%
test_data = test_data.to_numpy()

# %%
test_label = test_label.to_numpy().astype('float32')

# %%
#train_set = np.array(train_set.as_matrix())
#train_label = np.array(pd.DataFrame(train_label).as_matrix())

# %%
print(type(train_data))
print(type(train_label))
print(type(test_data))
print(type(test_label))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(train_data.dtype)
print(train_label.dtype)
print(test_label.dtype)
print(test_data.dtype)
# Out:
# float64
# float32
# float32
# float64

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# - Model : 1 hidden layers including 16 unit.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(train_data.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1,  activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               4352
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 12,673
# Trainable params: 12,673
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)

# %%
from tensorflow.keras import optimizers

model.compile(optimizer = 'RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# - Train the Model with Epochs (100).

# %%
history = model.fit(train_data, train_label, validation_split=0.25, epochs= 75, batch_size = 32)
# Out:
# Epoch 1/75
# 5/5 [==============================] - 1s 53ms/step - loss: 0.6649 - accuracy: 0.6539 - val_loss: 0.5517 - val_accuracy: 0.7736
# Epoch 2/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5522 - accuracy: 0.8206 - val_loss: 0.4787 - val_accuracy: 0.8679
# Epoch 3/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4894 - accuracy: 0.8416 - val_loss: 0.4297 - val_accuracy: 0.8868
# Epoch 4/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4514 - accuracy: 0.8378 - val_loss: 0.3890 - val_accuracy: 0.9057
# Epoch 5/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3819 - accuracy: 0.9038 - val_loss: 0.3562 - val_accuracy: 0.9245
# Epoch 6/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3408 - accuracy: 0.9098 - val_loss: 0.3285 - val_accuracy: 0.9434
# Epoch 7/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3321 - accuracy: 0.9072 - val_loss: 0.2987 - val_accuracy: 0.9434
# Epoch 8/75
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2963 - accuracy: 0.9145 - val_loss: 0.2798 - val_accuracy: 0.9434
# Epoch 9/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2684 - accuracy: 0.9411 - val_loss: 0.2618 - val_accuracy: 0.9434
# Epoch 10/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2501 - accuracy: 0.9160 - val_loss: 0.2498 - val_accuracy: 0.9434
# Epoch 11/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2137 - accuracy: 0.9533 - val_loss: 0.2328 - val_accuracy: 0.9623
# Epoch 12/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2220 - accuracy: 0.9497 - val_loss: 0.2198 - val_accuracy: 0.9623
# Epoch 13/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1870 - accuracy: 0.9575 - val_loss: 0.2079 - val_accuracy: 0.9623
# Epoch 14/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2176 - accuracy: 0.9424 - val_loss: 0.2005 - val_accuracy: 0.9623
# Epoch 15/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2384 - accuracy: 0.9211 - val_loss: 0.1945 - val_accuracy: 0.9623
# Epoch 16/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1397 - accuracy: 0.9516 - val_loss: 0.1891 - val_accuracy: 0.9623
# Epoch 17/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1741 - accuracy: 0.9431 - val_loss: 0.1855 - val_accuracy: 0.9623
# Epoch 18/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1313 - accuracy: 0.9458 - val_loss: 0.1871 - val_accuracy: 0.9623
# Epoch 19/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1714 - accuracy: 0.9427 - val_loss: 0.1824 - val_accuracy: 0.9623
# Epoch 20/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1530 - accuracy: 0.9612 - val_loss: 0.1856 - val_accuracy: 0.9623
# Epoch 21/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1187 - accuracy: 0.9667 - val_loss: 0.1751 - val_accuracy: 0.9623
# Epoch 22/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1391 - accuracy: 0.9661 - val_loss: 0.1751 - val_accuracy: 0.9623
# Epoch 23/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1325 - accuracy: 0.9566 - val_loss: 0.1752 - val_accuracy: 0.9623
# Epoch 24/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1195 - accuracy: 0.9781 - val_loss: 0.1818 - val_accuracy: 0.9623
# Epoch 25/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0968 - accuracy: 0.9829 - val_loss: 0.1821 - val_accuracy: 0.9623
# Epoch 26/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1319 - accuracy: 0.9565 - val_loss: 0.1854 - val_accuracy: 0.9623
# Epoch 27/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 0.9642 - val_loss: 0.1810 - val_accuracy: 0.9623
# Epoch 28/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0880 - accuracy: 0.9817 - val_loss: 0.1795 - val_accuracy: 0.9434
# Epoch 29/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0984 - accuracy: 0.9617 - val_loss: 0.1762 - val_accuracy: 0.9623
# Epoch 30/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0956 - accuracy: 0.9816 - val_loss: 0.1756 - val_accuracy: 0.9623
# Epoch 31/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1024 - accuracy: 0.9720 - val_loss: 0.1771 - val_accuracy: 0.9623
# Epoch 32/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0994 - accuracy: 0.9720 - val_loss: 0.1832 - val_accuracy: 0.9434
# Epoch 33/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0719 - accuracy: 0.9836 - val_loss: 0.1805 - val_accuracy: 0.9623
# Epoch 34/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0531 - accuracy: 0.9893 - val_loss: 0.1813 - val_accuracy: 0.9434
# Epoch 35/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0572 - accuracy: 0.9871 - val_loss: 0.1901 - val_accuracy: 0.9623
# Epoch 36/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0975 - accuracy: 0.9741 - val_loss: 0.1821 - val_accuracy: 0.9623
# Epoch 37/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0590 - accuracy: 0.9781 - val_loss: 0.1945 - val_accuracy: 0.9434
# Epoch 38/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9820 - val_loss: 0.1869 - val_accuracy: 0.9434
# Epoch 39/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 0.1894 - val_accuracy: 0.9623
# Epoch 40/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0610 - accuracy: 0.9922 - val_loss: 0.1866 - val_accuracy: 0.9434
# Epoch 41/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0568 - accuracy: 0.9863 - val_loss: 0.1936 - val_accuracy: 0.9434
# Epoch 42/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0619 - accuracy: 0.9681 - val_loss: 0.1901 - val_accuracy: 0.9434
# Epoch 43/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0451 - accuracy: 0.9945 - val_loss: 0.2010 - val_accuracy: 0.9434
# Epoch 44/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0557 - accuracy: 0.9819 - val_loss: 0.1981 - val_accuracy: 0.9623
# Epoch 45/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0530 - accuracy: 0.9914 - val_loss: 0.2028 - val_accuracy: 0.9434
# Epoch 46/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9623
# Epoch 47/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0523 - accuracy: 0.9836 - val_loss: 0.2012 - val_accuracy: 0.9623
# Epoch 48/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0426 - accuracy: 0.9815 - val_loss: 0.1951 - val_accuracy: 0.9434
# Epoch 49/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9434
# Epoch 50/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0296 - accuracy: 0.9966 - val_loss: 0.1972 - val_accuracy: 0.9623
# Epoch 51/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0289 - accuracy: 0.9914 - val_loss: 0.1989 - val_accuracy: 0.9623
# Epoch 52/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0406 - accuracy: 0.9849 - val_loss: 0.1976 - val_accuracy: 0.9623
# Epoch 53/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0350 - accuracy: 0.9979 - val_loss: 0.1918 - val_accuracy: 0.9623
# Epoch 54/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0286 - accuracy: 0.9849 - val_loss: 0.1991 - val_accuracy: 0.9623
# Epoch 55/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0274 - accuracy: 0.9924 - val_loss: 0.2094 - val_accuracy: 0.9623
# Epoch 56/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0383 - accuracy: 0.9870 - val_loss: 0.2046 - val_accuracy: 0.9623
# Epoch 57/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9623
# Epoch 58/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0275 - accuracy: 0.9949 - val_loss: 0.2077 - val_accuracy: 0.9623
# Epoch 59/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0165 - accuracy: 0.9979 - val_loss: 0.2158 - val_accuracy: 0.9434
# Epoch 60/75
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9623
# Epoch 61/75
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0344 - accuracy: 0.9966 - val_loss: 0.2188 - val_accuracy: 0.9623
# Epoch 62/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0427 - accuracy: 0.9922 - val_loss: 0.2221 - val_accuracy: 0.9623
# Epoch 63/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0223 - accuracy: 0.9888 - val_loss: 0.2317 - val_accuracy: 0.9623
# Epoch 64/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.9623
# Epoch 65/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0279 - accuracy: 0.9979 - val_loss: 0.2239 - val_accuracy: 0.9623
# Epoch 66/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.2255 - val_accuracy: 0.9623
# Epoch 67/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9623
# Epoch 68/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9623
# Epoch 69/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0318 - accuracy: 0.9845 - val_loss: 0.2149 - val_accuracy: 0.9623
# Epoch 70/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.2201 - val_accuracy: 0.9811
# Epoch 71/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9811
# Epoch 72/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9623
# Epoch 73/75
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9623
# Epoch 74/75
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0137 - accuracy: 0.9979 - val_loss: 0.2585 - val_accuracy: 0.9434
# Epoch 75/75
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9811

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(75)
plt.plot(epochs, loss_values, 'ro', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, acc_values, 'ro', label='Training acc')
plt.plot(epochs, val_acc_values, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# - Evaluation Step
# - Prediction

# %%
score = model.evaluate(test_data, test_label)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3034 - accuracy: 0.9357

# %%
score
# Out:
# [0.3034432530403137, 0.9357143044471741]

# %% [markdown]
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**

# %%
predictions=model.predict(test_data)

# %%
y_pred = (predictions > 0.5)

# %%
tf.math.confusion_matrix(
    test_label, y_pred, num_classes=2, weights=None, dtype=tf.dtypes.int32,
    name=None
)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[47,  8],
#        [ 1, 84]], dtype=int32)>

# %%
 # It will evaluate the logical expression y_predict>0.25 and return True or False

# %%
np.count_nonzero(y_pred)
# Out:
# 92
